# %%
import pandas as pd
import tensorflow as tf
import keras as kr

# %%
df = pd.read_csv('train_dataset.csv', sep=";")
df.drop(labels=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1, inplace=True)
df
# Out:
#                                                QUESTION  \
# 0              Какие основания для получения 33 услуги?
# 1     Какие основания для получения предоставления д...
# 2     Какие основания для получения единовременной к...
# 3                    Какие основания для детской карты?
# 4     Какие условия являются обязательными для получ...
# ...                                                 ...
# 2728  Может ли получить выписку из ЕГРН бывший собст...
# 2729  В какой выписке из ЕГРН можно увидеть сведения...
# 2730  При приеме запросов о предоставлении сведений ...
# 2731  Следует ли изготавливать копии документов, с п...
# 2732  Будут ли в выписке из ЕГРН о правах отдельного...
#
#                                                  ANSWER
# 0     Заявителем является родитель (усыновитель) реб...
# 1     Заявителем является родитель (усыновитель) реб...
# 2     Заявителем является родитель (усыновитель) реб...
# 3     Заявителем является родитель (усыновитель) реб...
# 4     ребенок - гражданин РФ, имеющий место жительст...
# ...                                                 ...
# 2728  Да, бывший правообладатель может получить выпи...
# 2729  Сведения о снятых запрещениях и арестах будут ...
# 2730  При приеме запросов о предоставлении сведений ...
# 2731  При приеме запросов о предоставлении сведений ...
# 2732                                     Нет, не будут.
#
# [2733 rows x 2 columns]
